# %%
import pandas as pd
import numpy as np

def load_clean(path_or_url):
    # Method 1 (Load data, remove unecessary columns)
    gpu_df1 = (
        pd.read_csv(path_or_url)
        .drop(['Best_Resolution', 'Boost_Clock', 'DVI_Connection', 'Dedicated', 'DisplayPort_Connection', 'HDMI_Connection', 'Integrated', 'Open_GL', 'PSU', 'Power_Connector', 
               'ROPs', 'Resolution_WxH', 'SLI_Crossfire', 'Shader', 'VGA_Connection'], axis = 1, inplace = False)
    )
    
    #gpu_df1['Core_Speed'] = gpu_df1['Core_Speed'].map(lambda x: x.lstrip('\n-'))
    #gpu_df1['Release_Date'] = gpu_df1['Release_Date'].map(lambda x: x.lstrip('\n'))
    
    # Final (Remove unnecessary string values/deal with remaining missing data)
    gpu_df_end = (
        gpu_df1
        .replace(to_replace = '-', value = np.NaN, inplace = False)
        .replace(to_replace = ' Watts', value = ' W', inplace = False)
        .fillna({'Architecture':'Unknown', 'Core_Speed':'0 MHz', 'Max_Power':'0 W', 'Memory_Bandwidth':'0GB/sec', 
                 'Pixel_Rate':'0 GPixel/s', 'Release_Price':'$0.00', 'Texture_Rate':'0 GTexel/s'}, inplace = False)
    )
    return gpu_df_end

# %%
df = load_clean("../data/raw/gpu_specs.csv")

# %%
df.head()
# Out:
#   Architecture Core_Speed Direct_X L2_Cache Manufacturer  Max_Power    Memory  \
# 0  Tesla G92b     738 MHz  DX 10.0      0KB       Nvidia  141 Watts  1024 MB
# 1     R600 XT                DX 10      0KB          AMD  215 Watts   512 MB
# 2    R600 PRO                DX 10      0KB          AMD  200 Watts   512 MB
# 3       RV630                DX 10      0KB          AMD        0 W   256 MB
# 4       RV630                DX 10      0KB          AMD   45 Watts   256 MB
#
#   Memory_Bandwidth Memory_Bus Memory_Speed Memory_Type  \
# 0         64GB/sec   256 Bit      1000 MHz       GDDR3
# 1        106GB/sec   512 Bit       828 MHz       GDDR3
# 2       51.2GB/sec   256 Bit       800 MHz       GDDR3
# 3       36.8GB/sec   128 Bit      1150 MHz       GDDR4
# 4       22.4GB/sec   128 Bit       700 MHz       GDDR3
#
#                                 Name Notebook_GPU   Pixel_Rate Process  \
# 0                    GeForce GTS 150           No  12 GPixel/s    55nm
# 1            Radeon HD 2900 XT 512MB           No  12 GPixel/s    80nm
# 2                 Radeon HD 2900 Pro           No  10 GPixel/s    80nm
# 3  Radeon HD 2600 XT Diamond Edition           No   3 GPixel/s    65nm
# 4                  Radeon HD 2600 XT           No   3 GPixel/s    65nm
#
#    Release_Date Release_Price  TMUs Texture_Rate
# 0  01-Mar-2009          $0.00  64.0  47 GTexel/s
# 1  14-May-2007          $0.00  16.0  12 GTexel/s
# 2  07-Dec-2007          $0.00  16.0  10 GTexel/s
# 3  01-Jul-2007          $0.00   8.0   7 GTexel/s
# 4  28-Jun-2007          $0.00   8.0   6 GTexel/s
