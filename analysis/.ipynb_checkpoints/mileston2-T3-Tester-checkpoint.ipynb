# %%
import pandas as pd
import numpy as np
from scripts import New_Proj_Functions
gpu_clean = New_Proj_Functions.load_clean("../data/raw/gpu_specs.csv")
gpu_clean
# Out:
#                                    Name Architecture Core_Speed Direct_X  \
# 0                       GeForce GTS 150  Tesla G92b     738 MHz  DX 10.0
# 1               Radeon HD 2900 XT 512MB     R600 XT                DX 10
# 2                    Radeon HD 2900 Pro    R600 PRO                DX 10
# 3     Radeon HD 2600 XT Diamond Edition       RV630                DX 10
# 4                     Radeon HD 2600 XT       RV630                DX 10
# ...                                 ...          ...        ...      ...
# 3401         GeForce 6150 SE nForce 430       MCP61              DX 9.0c
# 3402              GeForce 6150 SE 256MB       MCP61              DX 9.0c
# 3403            GeForce 6100 nForce 405       MCP51                 DX 9
# 3404                       GeForce 6100       MCP51              DX 9.0c
# 3405                       GeForce 6200        NV43              DX 9.0c
#
#      L2_Cache Manufacturer  Max_Power    Memory Memory_Bandwidth Memory_Bus  \
# 0         0KB       Nvidia  141 Watts  1024 MB          64GB/sec   256 Bit
# 1         0KB          AMD  215 Watts   512 MB         106GB/sec   512 Bit
# 2         0KB          AMD  200 Watts   512 MB        51.2GB/sec   256 Bit
# 3         0KB          AMD        0 W   256 MB        36.8GB/sec   128 Bit
# 4         0KB          AMD   45 Watts   256 MB        22.4GB/sec   128 Bit
# ...       ...          ...        ...       ...              ...        ...
# 3401      0KB       Nvidia        0 W       NaN          0GB/sec   128 Bit
# 3402      0KB       Nvidia        0 W       NaN          0GB/sec   128 Bit
# 3403      0KB       Nvidia        0 W       NaN          0GB/sec        NaN
# 3404      0KB       Nvidia        0 W       NaN          0GB/sec   128 Bit
# 3405      0KB       Nvidia        0 W   256 MB         8.8GB/sec   128 Bit
#
#      Memory_Speed Memory_Type Notebook_GPU   Pixel_Rate Process  Release_Date  \
# 0        1000 MHz       GDDR3           No  12 GPixel/s    55nm  01-Mar-2009
# 1         828 MHz       GDDR3           No  12 GPixel/s    80nm  14-May-2007
# 2         800 MHz       GDDR3           No  10 GPixel/s    80nm  07-Dec-2007
# 3        1150 MHz       GDDR4           No   3 GPixel/s    65nm  01-Jul-2007
# 4         700 MHz       GDDR3           No   3 GPixel/s    65nm  28-Jun-2007
# ...           ...         ...          ...          ...     ...           ...
# 3401          NaN        DDR2           No   0 GPixel/s     NaN  01-Jun-2006
# 3402          NaN        DDR2           No   0 GPixel/s     NaN  01-Jun-2006
# 3403          NaN         NaN           No   0 GPixel/s     NaN  20-Oct-2005
# 3404          NaN        DDR2           No   0 GPixel/s     NaN  01-Nov-2005
# 3405      275 MHz        DDR2           No   0 GPixel/s     NaN  02-Jan-2004
#
#      Release_Price  TMUs Texture_Rate
# 0            $0.00  64.0  47 GTexel/s
# 1            $0.00  16.0  12 GTexel/s
# 2            $0.00  16.0  10 GTexel/s
# 3            $0.00   8.0   7 GTexel/s
# 4            $0.00   8.0   6 GTexel/s
# ...            ...   ...          ...
# 3401         $0.00   NaN   0 GTexel/s
# 3402         $0.00   NaN   0 GTexel/s
# 3403         $0.00   NaN   0 GTexel/s
# 3404         $0.00   NaN   0 GTexel/s
# 3405         $0.00   NaN   0 GTexel/s
#
# [3406 rows x 19 columns]

# %%
gpu_old = pd.read_csv("../data/raw/gpu_specs.csv")
gpu_old
# Out:
#      Architecture Best_Resolution Boost_Clock Core_Speed  DVI_Connection  \
# 0     Tesla G92b              NaN         NaN    738 MHz             2.0
# 1        R600 XT       1366 x 768         NaN       \n-              2.0
# 2       R600 PRO       1366 x 768         NaN       \n-              2.0
# 3          RV630       1024 x 768         NaN       \n-              2.0
# 4          RV630       1024 x 768         NaN       \n-              2.0
# ...           ...             ...         ...        ...             ...
# 3401       MCP61              NaN         NaN       \n-              1.0
# 3402       MCP61              NaN         NaN       \n-              0.0
# 3403       MCP51              NaN         NaN       \n-              0.0
# 3404       MCP51              NaN         NaN       \n-              NaN
# 3405        NV43              NaN         NaN       \n-              1.0
#
#      Dedicated Direct_X  DisplayPort_Connection  HDMI_Connection Integrated  \
# 0          Yes  DX 10.0                     NaN              0.0         No
# 1          Yes    DX 10                     NaN              0.0         No
# 2          Yes    DX 10                     NaN              0.0         No
# 3          Yes    DX 10                     NaN              0.0         No
# 4          Yes    DX 10                     NaN              0.0         No
# ...        ...      ...                     ...              ...        ...
# 3401        No  DX 9.0c                     NaN              1.0        Yes
# 3402        No  DX 9.0c                     NaN              0.0        Yes
# 3403       NaN     DX 9                     NaN              0.0        NaN
# 3404        No  DX 9.0c                     NaN              0.0        Yes
# 3405       Yes  DX 9.0c                     NaN              0.0         No
#
#       ... Process ROPs    Release_Date Release_Price Resolution_WxH  \
# 0     ...    55nm   16  \n01-Mar-2009            NaN      2560x1600
# 1     ...    80nm   16  \n14-May-2007            NaN      2560x1600
# 2     ...    80nm   16  \n07-Dec-2007            NaN      2560x1600
# 3     ...    65nm    4  \n01-Jul-2007            NaN      2560x1600
# 4     ...    65nm    4  \n28-Jun-2007            NaN      2560x1600
# ...   ...     ...  ...             ...           ...            ...
# 3401  ...     NaN  NaN  \n01-Jun-2006            NaN      2560x1600
# 3402  ...     NaN  NaN  \n01-Jun-2006            NaN      2560x1600
# 3403  ...     NaN  NaN  \n20-Oct-2005            NaN            NaN
# 3404  ...     NaN  NaN  \n01-Nov-2005            NaN      2560x1600
# 3405  ...     NaN  NaN  \n02-Jan-2004            NaN      2560x1600
#
#      SLI_Crossfire Shader  TMUs Texture_Rate VGA_Connection
# 0              Yes    4.0  64.0  47 GTexel/s            0.0
# 1              Yes    4.0  16.0  12 GTexel/s            0.0
# 2              Yes    4.0  16.0  10 GTexel/s            0.0
# 3              Yes    4.0   8.0   7 GTexel/s            0.0
# 4              Yes    4.0   8.0   6 GTexel/s            0.0
# ...            ...    ...   ...          ...            ...
# 3401            No    3.0   NaN          NaN            1.0
# 3402            No    3.0   NaN          NaN            1.0
# 3403            No    NaN   NaN          NaN            0.0
# 3404            No    3.0   NaN          NaN            1.0
# 3405            No    3.0   NaN          NaN            1.0
#
# [3406 rows x 34 columns]

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []
